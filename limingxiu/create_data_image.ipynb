# %%
# from signal import pidfd_send_signal
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# import seaborn as sns
# sns.set(color_codes=True)
# plt.style.use("bmh")
# mpl.rcParams["font.sans-serif"] = ["SimHei"]
# mpl.rcParams["axes.unicode_minus"] = False

plt.figure(figsize=(6, 3))
plt.gca().patch.set_facecolor("w")
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_color('k')
plt.gca().spines['bottom'].set_color('k')
plt.grid(False)

#柱高信息
BeautyGAN = [6.75, 4.38,  4.75]
LAND =      [1.88, 2.75,  2.75]
PSGAN =     [5.04, 4.04,  4.25]
SCGAN =     [6.09, 6.21,  5.63]
SSAT =      [21.24,16.37, 20.37]
CRAT =      [59.00,66.25, 62.25]

bar_width = 0.25
tick_label = ['BeautyGAN','LAND','PSGAN','SCGAN','SSAT','CRAT']
Quality = [6.75, 1.88, 5.04, 6.09, 21.24, 59.00]
Detail = [4.38, 2.75, 4.04, 6.21, 16.37, 66.25]
Overrall = [4.75, 2.75, 4.25, 5.63, 20.37, 62.25]
X = np.arange(len(Quality))




#显示每个柱的具体高度
# for x,y in zip(X,Quality):
#     plt.text(x+0.005,y+0.005,'%.3f' %y, ha='center',va='bottom')
    
# for x,y in zip(X,Detail):
#     plt.text(x+0.24,y+0.005,'%.3f' %y, ha='center',va='bottom')
    
# for x,y in zip(X,Overrall):
#     plt.text(x+0.5,y+0.005,'%.3f' %y, ha='center',va='bottom')
    
#绘制柱状图    
x1 = X
x2 = X + bar_width + 0.03
x3 = X + bar_width * 2 + 0.06

plt.bar(x1, Quality, bar_width, align="center", color="#E67F3B", label="Quality", alpha=1)
plt.bar(x2, Detail, bar_width, align="center", color="#F8BF33", label="Detail", alpha=1)
plt.bar(x3, Overrall, bar_width, align="center", color="#77AE51", label="Overrall", alpha=1)

# plt.xlabel("X")
plt.ylabel("Ration(%)")
plt.title('Picture Name')

plt.xticks(X+bar_width/2, tick_label)
#显示图例
plt.legend()
#plt.show()
plt.savefig('result.png', dpi=3000)

# %% [markdown]
# ## Source code

# %% [markdown]
# import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib as mpl
# import seaborn as sns
# sns.set(color_codes=True)
# mpl.rcParams["font.sans-serif"] = ["SimHei"]
# mpl.rcParams["axes.unicode_minus"] = False
#
# #柱高信息
# Y = [0.87,0.878,0.872,0.885,0.876]
# Y1 = [0.618,0.634,0.637,0.638,0.629]
# X = np.arange(len(Y))
#
# bar_width = 0.25
# tick_label = ['A','B','C','D','E','F']
#
# #显示每个柱的具体高度
# for x,y in zip(X,Y):
#     plt.text(x+0.005,y+0.005,'%.3f' %y, ha='center',va='bottom')
#
# for x,y1 in zip(X,Y1):
#     plt.text(x+0.24,y1+0.005,'%.3f' %y1, ha='center',va='bottom')
#
# #绘制柱状图
# plt.bar(X, Y, bar_width, align="center", color="red", label="AUC", alpha=0.5)
# plt.bar(X+bar_width, Y1, bar_width, color="purple", align="center", \
#         label="MAP", alpha=0.5)
#
# plt.xlabel("X")
# plt.ylabel("Y")
# plt.title('Picture Name')
#
# plt.xticks(X+bar_width/2, tick_label)
# #显示图例
# plt.legend()
# #plt.show()
# plt.savefig('result.png',dpi = 400)
